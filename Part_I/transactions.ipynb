# %%
import pandas as pd
data = pd.read_csv('transactions.tsv', sep='\t')
data.info()
data.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
# transaction.value    2000 non-null float64
# gender               2000 non-null object
# store.type           2000 non-null object
# dtypes: float64(1), object(2)
# memory usage: 47.0+ KB
#         transaction.value gender  store.type
# count         2000.000000   2000        2000
# unique                NaN      2           4
# top                   NaN   Male  Superstore
# freq                  NaN   1014         829
# mean           286.176050    NaN         NaN
# std           4042.830224    NaN         NaN
# min              0.460000    NaN         NaN
# 25%             22.127500    NaN         NaN
# 50%             47.275000    NaN         NaN
# 75%            173.665000    NaN         NaN
# max         150032.000000    NaN         NaN

# %%
data[data['transaction.value'] > 1000]
# Out:
#       transaction.value  gender  store.type
# 5               1414.49    Male  Superstore
# 50            100000.00  Female       Extra
# 86              1012.65  Female       Metro
# 167             1108.64    Male       Extra
# 352             1406.75  Female       Metro
# 362             1479.89    Male  Superstore
# 423             1162.28    Male       Extra
# 452             1137.81  Female       Extra
# 461             1282.86    Male  Superstore
# 481             1701.38  Female       Extra
# 484             1295.91    Male       Extra
# 640             1398.27    Male  Superstore
# 662             1399.52  Female       Extra
# 667             2502.39  Female       Extra
# 675             2288.23    Male       Extra
# 712             1321.08  Female  Superstore
# 954             1169.49  Female       Metro
# 971             1436.02  Female     Express
# 990             1443.61  Female  Superstore
# 1004            1170.48  Female       Extra
# ...

# %%
data = data.drop(index=[50, 1428])
data.groupby('store.type').mean()
# Out:
#             transaction.value
# store.type
# Express             86.349468
# Extra              285.118953
# Metro              113.176605
# Superstore         155.166490
